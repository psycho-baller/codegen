# %%
import ast
import os
import networkx as nx
import matplotlib.pyplot as plt

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                graph.add_node(module_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    pos = nx.spring_layout(graph)
    plt.figure(figsize=(12, 12))
    nx.draw(graph, pos, with_labels=True, node_size=300, node_color="skyblue", font_size=10, font_weight="bold", edge_color="gray")
    plt.title("Python Codebase Import Graph")
    plt.show()

if __name__ == "__main__":
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    visualize_graph(import_graph)

# %% [markdown]
# # Color code the node based on the type of file it is

# %%
import ast
import os
import networkx as nx
import matplotlib.pyplot as plt

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                folder_name = os.path.relpath(root, codebase_path).split(os.sep)[0]
                print(folder_name)
                graph.add_node(module_name, folder=folder_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    pos = nx.spring_layout(graph)
    
    # Define color mapping for different folders
    color_map = {
        'controllers': 'skyblue',
        'models': 'lightgreen',
        'services': 'lightcoral',
        'utils': 'khaki',
    }
    
    # Assign colors based on folder
    node_colors = []
    for node in graph.nodes(data=True):
        folder = node[1].get('folder', 'default')
        node_colors.append(color_map.get(folder, 'gray'))
    
    plt.figure(figsize=(12, 12))
    nx.draw(graph, pos, with_labels=True, node_size=300, node_color=node_colors, font_size=10, font_weight="bold", edge_color="gray")
    plt.title("Python Codebase Import Graph")
    plt.show()

if __name__ == "__main__":
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    visualize_graph(import_graph)
# Out:
# requirements.txt
# README.md
# .
# utils
# utils
# utils
# models
# models
# models
# config
# HEAD
# description
# index
# packed-refs
# FETCH_HEAD
# pack-5834d325511f442431413cc2b5e5a8f9d9944453.rev
# pack-5834d325511f442431413cc2b5e5a8f9d9944453.idx
# pack-5834d325511f442431413cc2b5e5a8f9d9944453.pack
# exclude
# HEAD
# main
# HEAD
# commit-msg.sample
# pre-rebase.sample
# sendemail-validate.sample
# pre-commit.sample
# applypatch-msg.sample
# fsmonitor-watchman.sample
# pre-receive.sample
# prepare-commit-msg.sample
# post-update.sample
# pre-merge-commit.sample
# pre-applypatch.sample
# pre-push.sample
# update.sample
# push-to-checkout.sample
# main
# HEAD
# controllers
# controllers
# controllers
# services
# services
# services
# services
# services

# %% [markdown]
# # Increase the size of the arrow to make it more visible

# %%
import ast
import os
import networkx as nx
import matplotlib.pyplot as plt

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                folder_name = os.path.relpath(root, codebase_path).split(os.sep)[0]
                graph.add_node(module_name, folder=folder_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    pos = nx.spring_layout(graph)
    
    # Define color mapping for different folders
    color_map = {
        'controllers': 'skyblue',
        'models': 'lightgreen',
        'services': 'lightcoral',
        'utils': 'khaki',
    }
    
    # Assign colors based on folder
    node_colors = []
    for node in graph.nodes(data=True):
        folder = node[1].get('folder', 'default')
        node_colors.append(color_map.get(folder, 'gray'))
    
    plt.figure(figsize=(12, 12))
    nx.draw(graph, pos, with_labels=True, node_size=300, node_color=node_colors, font_size=10, font_weight="bold", edge_color="gray", arrowsize=20, width=2)
    plt.title("Python Codebase Import Graph")
    plt.show()

if __name__ == "__main__":
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    visualize_graph(import_graph)

# %% [markdown]
# # Have different sizes based on the number of exports the file does.

# %%
import ast
import os
import networkx as nx
import matplotlib.pyplot as plt

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                folder_name = os.path.relpath(root, codebase_path).split(os.sep)[0]
                graph.add_node(module_name, folder=folder_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    pos = nx.spring_layout(graph)
    
    # Define color mapping for different folders
    color_map = {
        'controllers': 'skyblue',
        'models': 'lightgreen',
        'services': 'lightcoral',
        'utils': 'khaki',
    }
    
    # Assign colors based on folder
    node_colors = []
    node_sizes = []
    for node in graph.nodes(data=True):
        folder = node[1].get('folder', 'default')
        node_colors.append(color_map.get(folder, 'gray'))
        # Set node size based on the number of imports (outgoing edges)
        node_sizes.append(200 + 200 * graph.out_degree(node[0]))
    
    plt.figure(figsize=(12, 12))
    nx.draw(graph, pos, with_labels=True, node_size=node_sizes, node_color=node_colors, font_size=10, font_weight="bold", edge_color="gray", arrowsize=20, width=2)
    plt.title("Python Codebase Import Graph")
    plt.show()

if __name__ == "__main__":
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    visualize_graph(import_graph)

# %% [markdown]
# # Space things out more for clarity

# %%
import ast
import os
import networkx as nx
import matplotlib.pyplot as plt

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                folder_name = os.path.relpath(root, codebase_path).split(os.sep)[0]
                graph.add_node(module_name, folder=folder_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    # Increase the k parameter to space out the nodes more
    pos = nx.spring_layout(graph, k=0.3, iterations=50)
    
    # Define color mapping for different folders
    color_map = {
        'controllers': 'skyblue',
        'models': 'lightgreen',
        'services': 'lightcoral',
        'utils': 'khaki',
    }
    
    # Assign colors based on folder
    node_colors = []
    node_sizes = []
    for node in graph.nodes(data=True):
        folder = node[1].get('folder', 'default')
        node_colors.append(color_map.get(folder, 'gray'))
        # Set node size based on the number of imports (outgoing edges)
        node_sizes.append(200 + 200 * graph.out_degree(node[0]))
    
    plt.figure(figsize=(15, 15))
    nx.draw(graph, pos, with_labels=True, node_size=node_sizes, node_color=node_colors, font_size=10, font_weight="bold", edge_color="gray", arrowsize=20, width=2)
    plt.title("Python Codebase Import Graph")
    plt.show()

if __name__ == "__main__":
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    visualize_graph(import_graph)

# %%
import ast
import os
import networkx as nx
import plotly.graph_objects as go
from dash import Dash, dcc, html, Input, Output

def parse_imports(file_path):
    with open(file_path, 'r') as file:
        tree = ast.parse(file.read(), filename=file_path)
    
    imports = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Import):
            for alias in node.names:
                imports.append(alias.name)
        elif isinstance(node, ast.ImportFrom):
            module = node.module
            for alias in node.names:
                imports.append(f"{module}.{alias.name}")
    return imports

def build_import_graph(codebase_path):
    graph = nx.DiGraph()
    
    for root, _, files in os.walk(codebase_path):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                imports = parse_imports(file_path)
                module_name = os.path.relpath(file_path, codebase_path).replace(os.sep, '.')[:-3]
                folder_name = os.path.relpath(root, codebase_path).split(os.sep)[0]
                graph.add_node(module_name, folder=folder_name)
                for imp in imports:
                    graph.add_edge(module_name, imp)
    
    return graph

def visualize_graph(graph):
    pos = nx.spring_layout(graph, k=0.3, iterations=50)
    
    edge_x = []
    edge_y = []
    for edge in graph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.append(x0)
        edge_x.append(x1)
        edge_x.append(None)
        edge_y.append(y0)
        edge_y.append(y1)
        edge_y.append(None)

    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=2, color='#888'),
        hoverinfo='none',
        mode='lines')

    node_x = []
    node_y = []
    node_sizes = []
    node_colors = []
    color_map = {
        'controllers': 'skyblue',
        'models': 'lightgreen',
        'services': 'lightcoral',
        'utils': 'khaki',
    }
    for node in graph.nodes(data=True):
        x, y = pos[node[0]]
        node_x.append(x)
        node_y.append(y)
        folder = node[1].get('folder', 'default')
        node_colors.append(color_map.get(folder, 'gray'))
        node_sizes.append(200 + 200 * graph.out_degree(node[0]))

    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode='markers',
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='YlGnBu',
            size=node_sizes,
            color=node_colors,
            colorbar=dict(
                thickness=15,
                title='Node Connections',
                xanchor='left',
                titleside='right'
            ),
            line_width=2))

    node_text = []
    for node in graph.nodes():
        node_text.append(node)
    node_trace.text = node_text

    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title='Python Codebase Import Graph',
                        titlefont_size=16,
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20,l=5,r=5,t=40),
                        annotations=[ dict(
                            text="Python Codebase Import Graph",
                            showarrow=False,
                            xref="paper", yref="paper") ],
                        xaxis=dict(showgrid=False, zeroline=False),
                        yaxis=dict(showgrid=False, zeroline=False))
                    )
    return fig

app = Dash(__name__)

app.layout = html.Div([
    dcc.Graph(id='import-graph'),
    dcc.Interval(
        id='interval-component',
        interval=60*1000,  # in milliseconds
        n_intervals=0
    )
])

@app.callback(
    Output('import-graph', 'figure'),
    Input('interval-component', 'n_intervals')
)
def update_graph(n):
    codebase_path = "repo"
    import_graph = build_import_graph(codebase_path)
    fig = visualize_graph(import_graph)
    return fig

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
